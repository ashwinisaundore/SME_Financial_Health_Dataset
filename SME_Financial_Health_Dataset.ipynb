# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\ashwini\\Downloads\\SME_Financial_Health.csv")

# %%
df.head()
# Out:
#   Business_ID       Industry  Employee_Count   Revenue   Expenses  \
# 0     B204211  Manufacturing              44  500000.0  418668.96
# 1     B207384            NaN              36  500000.0  455318.94
# 2     B200617         Retail              42  500000.0  423618.18
# 3     B206660         Retail              38  500000.0  501799.82
# 4     B209691         Retail              20  500000.0  361698.58
#
#    Profit_Margin  Loans_Taken  Loan_Default  Cash_Reserves  \
# 0          16.27            0             0       68915.56
# 1           8.94            0             0       53613.53
# 2          15.28            1             0       66268.67
# 3            NaN            1             0       22321.72
# 4          27.66            1             0       61275.72
#
#    Financial_Stress_Score  Financial_Stress_Flag
# 0                   49.30                      0
# 1                   53.23                      0
# 2                   51.64                      0
# ...

# %%
df.tail()
# Out:
#      Business_ID       Industry  Employee_Count   Revenue   Expenses  \
# 9995     B209966  Manufacturing              48  500000.0  332836.72
# 9996     B201243         Retail              58  500000.0  465458.83
# 9997     B209042         Retail              26  500000.0  417239.09
# 9998     B206791       Services              13  500000.0  317260.92
# 9999     B201225           Food              24  500000.0  413409.89
#
#       Profit_Margin  Loans_Taken  Loan_Default  Cash_Reserves  \
# 9995          33.43            0             0      108594.16
# 9996           6.91            0             0            NaN
# 9997          16.55            1             0       84512.21
# 9998          36.55            0             0      118187.32
# 9999          17.32            0             0       76928.38
#
#       Financial_Stress_Score  Financial_Stress_Flag
# 9995                   55.46                      0
# 9996                   53.86                      0
# ...

# %%
df.describe()
# Out:
#        Employee_Count       Revenue      Expenses  Profit_Margin  \
# count    10000.000000  1.000000e+04  1.000000e+04    9596.000000
# mean        27.127200  5.652233e+05  4.409846e+05      22.094102
# std         14.814721  3.434931e+05  2.723775e+05       6.891848
# min          3.000000  5.000000e+05  2.521313e+05      -2.720000
# 25%         16.000000  5.000000e+05  3.695168e+05      17.477500
# 50%         26.000000  5.000000e+05  3.935344e+05      22.150000
# 75%         37.000000  5.000000e+05  4.206213e+05      26.770000
# max         81.000000  5.662667e+06  4.128449e+06      52.430000
#
#         Loans_Taken  Loan_Default  Cash_Reserves  Financial_Stress_Score  \
# count  10000.000000  10000.000000   9.601000e+03            10000.000000
# mean       0.330000      0.046900   8.386058e+04               51.741313
# std        0.470236      0.211435   6.361054e+04                6.707060
# min        0.000000      0.000000   0.000000e+00               30.390000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Business_ID             10000 non-null  object
#  1   Industry                9602 non-null   object
#  2   Employee_Count          10000 non-null  int64
#  3   Revenue                 10000 non-null  float64
#  4   Expenses                10000 non-null  float64
#  5   Profit_Margin           9596 non-null   float64
#  6   Loans_Taken             10000 non-null  int64
#  7   Loan_Default            10000 non-null  int64
#  8   Cash_Reserves           9601 non-null   float64
#  9   Financial_Stress_Score  10000 non-null  float64
#  10  Financial_Stress_Flag   10000 non-null  int64
# dtypes: float64(5), int64(4), object(2)
# memory usage: 859.5+ KB

# %%
df.describe(include = "all")
# Out:
#        Business_ID Industry  Employee_Count       Revenue      Expenses  \
# count        10000     9602    10000.000000  1.000000e+04  1.000000e+04
# unique        9902       12             NaN           NaN           NaN
# top        B201764   Retail             NaN           NaN           NaN
# freq             2     2244             NaN           NaN           NaN
# mean           NaN      NaN       27.127200  5.652233e+05  4.409846e+05
# std            NaN      NaN       14.814721  3.434931e+05  2.723775e+05
# min            NaN      NaN        3.000000  5.000000e+05  2.521313e+05
# 25%            NaN      NaN       16.000000  5.000000e+05  3.695168e+05
# 50%            NaN      NaN       26.000000  5.000000e+05  3.935344e+05
# 75%            NaN      NaN       37.000000  5.000000e+05  4.206213e+05
# max            NaN      NaN       81.000000  5.662667e+06  4.128449e+06
#
#         Profit_Margin   Loans_Taken  Loan_Default  Cash_Reserves  \
# ...

# %% [markdown]
# **1. Business_ID**
# - As the count in the business_ID feature is **10000** it has **no missing values.**
# - In this feature there are **9902 unique values**
# - **B201764** is the most **frequent business_ID** which has been **repeated 2 times.**
#
# **2. Industry**
# - As the count in the Industry feature is **9602** it has **missing values**.
# - In this feature there are **12 unique values**
# - **Retail** is the most **frequent Industry** which has been **repeated 2244 times.**
#
# **3. Employee_Count**
# - As the count in the Employee_Count feature is **10000** it has **no missing values.**
# - The **mean average is 27.12** and **standard deviation is 14.81** in this observation we see that the data is **less variated.**
# - In this feature **3 is minimum value** and **81 is the maximum value**
# - In this feature **25%** of Employee_Count lies **below 16**
# - In this feature **50%** of Employee_Count lies **below 26**
# - In this feature **75%** of Employee_Count lies **below 37**
#
# **4. Revenue**
# - As the count in the Revenue feature is **1.000000e+04** it has **no missing values.**
# - The **mean average is 5.652233e+05** and **standard deviation is 3.434931e+05** in this observation we see that the data is **less variated.**
# - In this feature **5.000000e+05 is minimum value** and **5.662667e+06 is the maximum value**
# - In this feature **25%** of Revenue lies **below 5.000000e+05**
# - In this feature **50%** of Revenue lies **below 5.000000e+05**
# - In this feature **75%** of Revenue lies **below 5.000000e+05**
#
# **5. Expenses**
# - As the count in the Expenses feature is **1.000000e+04** it has **no missing values.**
# - The **mean average is 4.409846e+05** and **standard deviation is 2.723775e+05** in this observation we see that the data is **less variated.**
# - In this feature **2.521313e+05 is minimum value** and **4.128449e+06 is the maximum value**
# - In this feature **25%** of Expenses lies **below 3.695168e+05**
# - In this feature **50%** of Expenses lies **below 3.935344e+05**
# - In this feature **75%** of Expenses lies **below 4.206213e+05**
#
# **6. Profit_Margin**
# - As the count in the Profit_Margin feature is **9596** it has **missing values.**
# - The **mean average is 22.09** and **standard deviation is 6.89** in this observation we see that the data is **less variated.**
# - In this feature **-2.72 is minimum value** and **52.43 is the maximum value**
# - In this feature **25%** of Profit_Margin lies **below 17.47**
# - In this feature **50%** of Profit_Margin lies **below 22.15**
# - In this feature **75%** of Profit_Margin lies **below 26.77**
#
# **7. Loans_Taken**
# - As the count in the Loans_Taken feature is **10000** it has **no missing values.**
# - The **mean average is 0.33** and **standard deviation is 0.47** in this observation we see that the data is **more variated.**
# - In this feature **0 is minimum value** and **1 is the maximum value**
# - In this feature **25%** of Loans_Taken lies **below 0**
# - In this feature **50%** of Loans_Taken lies **below 0**
# - In this feature **75%** of Loans_Taken lies **below 1**
#
# **8. Loan_Default**
# - As the count in the Loan_Default feature is **10000** it has **no missing values.**
# - The **mean average is 0.04** and **standard deviation is 0.21** in this observation we see that the data is **more variated.**
# - In this feature **0 is minimum value** and **1 is the maximum value**
# - In this feature **25%** of Loan_Default lies **below 0**
# - In this feature **50%** of Loan_Default lies **below 0**
# - In this feature **75%** of Loan_Default lies **below 0**
#
# **9. Cash_Reserves**
# - As the count in the Cash_Reserves feature is **9.601000e+03** it has **missing values.**
# - The **mean average is 8.386058e+04** and **standard deviation is 6.361054e+04** in this observation we see that the data is **less variated.**
# - In this feature **0 is minimum value** and **1.501104e+06	 is the maximum value**
# - In this feature **25%** of Cash_Reserves lies **below 5.765217e+04**
# - In this feature **50%** of Cash_Reserves lies **below 7.413978e+04**
# - In this feature **75%** of Cash_Reserves lies **below 9.319470e+04**
#
# **10. Financial_Stress_Score**
# - As the count in the Financial_Stress_Score feature is **10000** it has **no missing values.**
# - The **mean average is 51.74** and **standard deviation is 6.70** in this observation we see that the data is **less variated.**
# - In this feature **30.39 is minimum value** and **82.01 is the maximum value**
# - In this feature **25%** of Financial_Stress_Score lies **below 47.36**
# - In this feature **50%** of Financial_Stress_Score lies **below 51.36**
# - In this feature **75%** of Financial_Stress_Score lies **below 55.61**
#
# **11. Financial_Stress_Flag**
# - As the count in the Financial_Stress_Flag feature is **10000** it has **no missing values.**
# - The **mean average is 0.09** and **standard deviation is 0.29** in this observation we see that the data is **more variated.**
# - In this feature **0 is minimum value** and **1 is the maximum value**
# - In this feature **25%** of Financial_Stress_Flag lies **below 0**
# - In this feature **50%** of Financial_Stress_Flag lies **below 0**
# - In this feature **75%** of Financial_Stress_Flag lies **below 0**

# %%
df.isna()
# Out:
#       Business_ID  Industry  Employee_Count  Revenue  Expenses  Profit_Margin  \
# 0           False     False           False    False     False          False
# 1           False      True           False    False     False          False
# 2           False     False           False    False     False          False
# 3           False     False           False    False     False           True
# 4           False     False           False    False     False          False
# ...           ...       ...             ...      ...       ...            ...
# 9995        False     False           False    False     False          False
# 9996        False     False           False    False     False          False
# 9997        False     False           False    False     False          False
# 9998        False     False           False    False     False          False
# 9999        False     False           False    False     False          False
#
# ...

# %%
df.isnull().sum()
# Out:
# Business_ID                 0
# Industry                  398
# Employee_Count              0
# Revenue                     0
# Expenses                    0
# Profit_Margin             404
# Loans_Taken                 0
# Loan_Default                0
# Cash_Reserves             399
# Financial_Stress_Score      0
# Financial_Stress_Flag       0
# dtype: int64

# %%
df.dtypes
# Out:
# Business_ID                object
# Industry                   object
# Employee_Count              int64
# Revenue                   float64
# Expenses                  float64
# Profit_Margin             float64
# Loans_Taken                 int64
# Loan_Default                int64
# Cash_Reserves             float64
# Financial_Stress_Score    float64
# Financial_Stress_Flag       int64
# dtype: object

# %%
df['Industry'].unique()
# Out:
# array(['Manufacturing', nan, 'Retail', 'Services', 'retail', 'Healthcare',
#        'Food', 'IT', 'manufacturing', 'food', 'services', 'healthcare',
#        'it'], dtype=object)

# %%
df['Industry'] = df['Industry'].fillna('Unknown')

# %%
df['Profit_Margin'] = df['Profit_Margin'].fillna(df['Profit_Margin'].median())

# %%
df['Cash_Reserves'] = df['Cash_Reserves'].fillna(df['Cash_Reserves'].mean())

# %%
df.isna().sum()
# Out:
# Business_ID               0
# Industry                  0
# Employee_Count            0
# Revenue                   0
# Expenses                  0
# Profit_Margin             0
# Loans_Taken               0
# Loan_Default              0
# Cash_Reserves             0
# Financial_Stress_Score    0
# Financial_Stress_Flag     0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(98)

# %%
df[df.duplicated()]
# Out:
#      Business_ID       Industry  Employee_Count   Revenue   Expenses  \
# 1304     B200130       Services              33  500000.0  337097.42
# 1759     B200625       Services               7  500000.0  382428.98
# 2660     B209014         Retail              28  500000.0  478227.01
# 2736     B204161         Retail              23  500000.0  424249.23
# 3211     B206343       Services               3  500000.0  394610.21
# ...          ...            ...             ...       ...        ...
# 9612     B201125       Services              12  500000.0  405421.16
# 9722     B201321         Retail              59  500000.0  415113.73
# 9873     B202370  Manufacturing              41  500000.0  416172.41
# 9909     B203304  Manufacturing              47  500000.0  397264.92
# 9964     B203207       Services              32  500000.0  365856.31
#
#       Profit_Margin  Loans_Taken  Loan_Default  Cash_Reserves  \
# 1304          32.58            0             0       95993.15
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Business_ID, Industry, Employee_Count, Revenue, Expenses, Profit_Margin, Loans_Taken, Loan_Default, Cash_Reserves, Financial_Stress_Score, Financial_Stress_Flag]
# Index: []

# %%
df.shape
# Out:
# (9902, 11)

# %%
df.dtypes
# Out:
# Business_ID                object
# Industry                   object
# Employee_Count              int64
# Revenue                   float64
# Expenses                  float64
# Profit_Margin             float64
# Loans_Taken                 int64
# Loan_Default                int64
# Cash_Reserves             float64
# Financial_Stress_Score    float64
# Financial_Stress_Flag       int64
# dtype: object

# %%
df['Industry'].nunique()
# Out:
# 13

# %%
df['Industry'].unique()
# Out:
# array(['Manufacturing', 'Unknown', 'Retail', 'Services', 'retail',
#        'Healthcare', 'Food', 'IT', 'manufacturing', 'food', 'services',
#        'healthcare', 'it'], dtype=object)

# %%
df['Industry'].value_counts()
# Out:
# Industry
# Retail           2223
# Services         1900
# Manufacturing    1629
# Food             1429
# IT               1055
# Healthcare        984
# Unknown           397
# retail             69
# food               46
# services           46
# manufacturing      44
# it                 41
# healthcare         39
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Business_ID', 'Industry', 'Employee_Count', 'Revenue', 'Expenses',
#        'Profit_Margin', 'Loans_Taken', 'Loan_Default', 'Cash_Reserves',
#        'Financial_Stress_Score', 'Financial_Stress_Flag'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Business_ID                object
# Industry                   object
# Employee_Count              int64
# Revenue                   float64
# Expenses                  float64
# Profit_Margin             float64
# Loans_Taken                 int64
# Loan_Default                int64
# Cash_Reserves             float64
# Financial_Stress_Score    float64
# Financial_Stress_Flag       int64
# dtype: object

# %%
df['Industry'] = df['Industry'].replace('manufacturing','Manufacturing')
df['Industry'] = df['Industry'].replace('retail','Retail')
df['Industry'] = df['Industry'].replace('services','Services')
df['Industry'] = df['Industry'].replace('food','Food')
df['Industry'] = df['Industry'].replace('healthcare','Healthcare')
df['Industry'] = df['Industry'].replace('it','IT')

# %%
plt.hist(df['Employee_Count'], color='skyblue', edgecolor='black')
plt.title('Employee_Count Distribution')
plt.xlabel('Employee_Count')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - **This histogram shows that the highest employee count 20 ,its frequency is above 2000.**
# - **The lowest employee count 80,its frequency is below 100.**

# %%
plt.hist(df['Revenue'], color='skyblue', edgecolor='black')
plt.title('Revenue Distribution')
plt.xlabel('Revenue')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - The highest revenue is from **0 to 1 lakh** and it has **frequency 9000.**
# - The lowest revenue is from **1 to 3.7 lakh**
# - **It is right skewed distribution**

# %%
plt.hist(df['Expenses'], color='skyblue', edgecolor='black')
plt.title('Expenses Distribution')
plt.xlabel('Expenses')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - The highest expenses is from **0 to 0.7 lakh** and it has frequency **above 8000.**
# - The lowest expenses is from **0.7 to 3.0 lakh**
# - **It is right skewed distribution**

# %%
plt.hist(df['Profit_Margin'], color='skyblue', edgecolor='black')
plt.title('Profit_Margin Distribution')
plt.xlabel('Profit_Margin')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - The highest profit margin is from **19 to 26** and it has frequency **above 3400.**
# - As the profit margin **0 to 19** and **31 to 46** shows the low frequency
# - **It is normal distribution** and more values on the higher end.

# %%
plt.hist(df['Cash_Reserves'], color='skyblue', edgecolor='black')
plt.title('Cash_Reserves Distribution')
plt.xlabel('Cash_Reserves')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - The highest cash reserves is from **0.0 to 0.1 lakh** and it has **frequency 9000.**
# - The lowest cash reserves is from **0.1 lakh to 0.9 lakh**
# - **It is right skewed distribution**

# %%
plt.hist(df['Financial_Stress_Score'], color='skyblue', edgecolor='black')
plt.title('Financial_Stress_Score Distribution')
plt.xlabel('Financial_Stress_Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - The highest profit margin is from **46 to 51** and it has frequency **above 2700.**
# - As the profit margin **31 to 46** and **56 to 80** shows the low frequency
# - **It is normal distribution** and more values on the higher end.

# %%
import seaborn as sns

# %%
sns.countplot(x = df["Industry"], data = df)
plt.title("CountPlot for Industry")
plt.xlabel("Industry")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# - **This graph shows that the highest industry is Retail,its count is above 2000.**
# - **Unknown,Healthcare it has very low count.**
# - **IT count is 1000.**
# - **Services  and Manufacturing count is above 1500.**
# - **Food count is above 1000.**

# %%
sns.countplot(x=df["Industry"], hue="Loans_Taken", data = df)
plt.title("Industry wise Loans_Taken")
plt.xlabel("Industry")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# - **This graph shows that Services company has the lowest loans taken.**
# - **Retail company has taken the highest loan count.**

# %%
plt.scatter(df['Profit_Margin'], df['Financial_Stress_Score'])
plt.xlabel("Profit_Margin")
plt.ylabel("Financial_Stress_Score")
plt.title("Profit_Margin vs Financial_Stress_Score")
plt.show()

# %% [markdown]
# - This scatter plot shows the **Negative correlation** between profit margin and finanical stress score.
# - The profit margin is **high cluster between 30 to 44** range
# - As the finanical stress score increases its profit margin is decreases.

# %%
plt.scatter(df['Cash_Reserves'], df['Financial_Stress_Score'])
plt.xlabel("Cash_Reserves")
plt.ylabel("Financial_Stress_Score")
plt.title("Cash_Reserves vs Financial_Stress_Score")
plt.show()

# %% [markdown]
# - There are **No strog correlation** between cash reserves and finanical stress score.
# - The cash reserves is high in the between **0.0 to 0.2 lakh in finanical stress score range**
# - The finanical stress score is shows the **high cluster in the bottom** and **less cluster in the top**
# - As the cash reserves increases its finanical stress score is decreases.

# %%
plt.scatter(df['Revenue'], df['Profit_Margin'])
plt.xlabel("Revenue")
plt.ylabel("Profit_Margin")
plt.title("Revenue vs Profit_Margin")
plt.show()

# %% [markdown]
# - There are **No strong correlation** between Revenue and Profit Margin.
# - The Profit Margin is high cluster in the between **0 to 1 lakh in revenue range**
# - The Profit Margin is shows the **high cluster**
# - As the Revenue increases its Profit Margin is decreases.

# %%
sns.boxplot(x = "Industry", y = "Employee_Count",data = df)
plt.title("Industry wise Employee_Count")
plt.xlabel("Industry")
plt.ylabel("Employee_Count")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# - **This graph shows that IT has the highest median,so it means that in IT industry employee count is higher.**
# - **Others are same level median so it means that in it employee count is not higher or not low.***

# %%
df.dtypes
# Out:
# Business_ID                object
# Industry                   object
# Employee_Count              int64
# Revenue                   float64
# Expenses                  float64
# Profit_Margin             float64
# Loans_Taken                 int64
# Loan_Default                int64
# Cash_Reserves             float64
# Financial_Stress_Score    float64
# Financial_Stress_Flag       int64
# dtype: object

# %%
sns.regplot(x= "Employee_Count",y = "Revenue",data = df)
plt.title("Employee_Count distribution by Revenue")
plt.xlabel("Employee_Count")
plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# - **The Visualization here indicates a Upward trend in employee count and revenue feature.**
# - **which means there are Positive relationship**
# - **The employee count is increases the revenue is also increases.**

# %%
sns.regplot(x= "Expenses",y = "Profit_Margin",data = df)
plt.title("Expenses distribution by Profit_Margin")
plt.xlabel("Expenses")
plt.ylabel("Profit_Margin")
plt.show()

# %% [markdown]
# - **The Visualization here indicates a Downward trend in expenses and profit margin feature.**
# - **which means there are Negative relationship**
# - **The expenses count is increases the profit margin is decreases.**

# %%
sns.regplot(x= "Loans_Taken",y = "Loan_Default",data = df)
plt.title("Loans_Taken distribution by Loan_Default")
plt.xlabel("Loans_Taken")
plt.ylabel("Loan_Default")
plt.show()

# %% [markdown]
# - **The Visualization here indicates a Upward trend in loans taken and loan default.**
# - **which means there are Positive relationship**
# - **The loans taken is increases the loans default is also increases.**

# %%
sns.regplot(x= "Cash_Reserves",y = "Financial_Stress_Score",data = df)
plt.title("Cash_Reserves distribution by Financial_Stress_Score")
plt.xlabel("Cash_Reserves")
plt.ylabel("Financial_Stress_Score")
plt.show()

# %% [markdown]
# - **The Visualization here indicates a Downward trend in cash reserves and Financial_Stress_Score feature.**
# - **which means there are Negative relationship**
# - **The cash reserves count is increases the Financial_Stress_Score is decreases.**

# %%
plt.figure(figsize=(7,6))
sns.scatterplot(data=df, x='Revenue', y='Expenses', hue='Industry', s=100)
plt.title("Sales vs Revenue by Region")
plt.show()

# %% [markdown]
# - **Clusters near lower revenue and expenses**
# - **Few industries have higher revenue**

# %%
df.dtypes
# Out:
# Business_ID                object
# Industry                   object
# Employee_Count              int64
# Revenue                   float64
# Expenses                  float64
# Profit_Margin             float64
# Loans_Taken                 int64
# Loan_Default                int64
# Cash_Reserves             float64
# Financial_Stress_Score    float64
# Financial_Stress_Flag       int64
# dtype: object

# %%
plt.figure(figsize = (7,6))
sns.scatterplot(x= "Employee_Count",y ="Revenue",hue="Industry",data = df)
plt.title("scatterplot for Employee_Count and Revenue")
plt.xlabel("Employee_Count")
plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# - **data points are strongly correlated with revenue 0 to 1 and employee count 0 to 55.**

# %%
plt.figure(figsize = (7,6))
sns.scatterplot(x= "Expenses",y ="Profit_Margin",hue="Industry",data = df)
plt.title("scatterplot for Expenses and Profit_Margin")
plt.xlabel("Expenses")
plt.ylabel("Profit_Margin")
plt.show()

# %% [markdown]
# - **In this graph profit margin 0 to 40 data points are strongly correlated with expenses 0.5 to 0.9.**
# - **Expenses 1.0 to 4.0 data points are weak.**

# %%
df1 = df.copy()

# %%
#label encoding 

from sklearn.preprocessing import LabelEncoder
nominal_col = ["Industry"]
encoder = LabelEncoder() # initializing label encoding
for col in nominal_col:
    df[col] = encoder.fit_transform(df[col])

# %%
df.head()
# Out:
#   Business_ID  Industry  Employee_Count   Revenue   Expenses  Profit_Margin  \
# 0     B204211         3              44  500000.0  418668.96          16.27
# 1     B207384         6              36  500000.0  455318.94           8.94
# 2     B200617         4              42  500000.0  423618.18          15.28
# 3     B206660         4              38  500000.0  501799.82          22.15
# 4     B209691         4              20  500000.0  361698.58          27.66
#
#    Loans_Taken  Loan_Default  Cash_Reserves  Financial_Stress_Score  \
# 0            0             0       68915.56                   49.30
# 1            0             0       53613.53                   53.23
# 2            1             0       66268.67                   51.64
# 3            1             0       22321.72                   58.37
# 4            1             0       61275.72                   43.21
#
#    Financial_Stress_Flag
# 0                      0
# 1                      0
# ...

# %%
plt.figure(figsize=(8,8))
loans_taken_by_industry = df.groupby('Industry')['Loans_Taken'].sum().head(6)

plt.pie(loans_taken_by_industry, labels=loans_taken_by_industry.index, autopct='%1.1f%%', startangle=90, wedgeprops={'width': 0.4})  # donut hole

plt.title('Loans Taken by Industry - Donut Chart')
plt.axis('equal')
plt.show()

# %% [markdown]
# - **Retail 33.2% dominates the loan taken**
# - **Manufacturing 22.3% and services 15.2% also take significant shares**
# - **Food 12.2%, Healthcare 8.3% and It 8.7% have small shares**

# %%
plt.figure(figsize=(8,8))
count_by_industry = df.groupby('Industry')['Loans_Taken'].sum().tail(6)

plt.pie(count_by_industry, labels=count_by_industry.index, autopct='%1.1f%%', startangle=90, wedgeprops={'width': 0.4})  # donut hole

plt.title('Loans Taken by Industry - Donut Chart')
plt.axis('equal')
plt.show()

# %% [markdown]
# - **Retail 33.7% dominates the loan taken**
# - **manufacturing 19.3%,it 13.3% and services 14.5% also take significant shares**
# - **food 8.4% and healthcare 10.8% have small shares**

# %%
import seaborn as sns

data = ['Loan_Default','Financial_Stress_Flag']
corr_data = df[data]
sns.heatmap(corr_data.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# - **The heatmap shows a 0.60 correlation between Loan_Default and Financial_Stress_Flag.**
# - **This means there is a strong positive relation between financial stress and loan default.**
# - **As the Financial_Stress_Flag increases, the chance of Loan_Default also increases with correlation 0.60.**
# - **The value 1.00 on the diagonal shows each feature is perfectly correlated with itself.**

# %%
 import seaborn as sns

sns.pairplot(df, vars=['Profit_Margin','Cash_Reserves','Financial_Stress_Score'],hue='Industry', palette='pastel')
plt.suptitle('Pairplot of Profit_Margin and Cash_Reserves by Financial_Stress_Score', y=1.02)
plt.show()

# %% [markdown]
# - **The profit margin and financial stress score shows the negtaive correleation with highest value 80**
# - **This means the profit margin increase, the financial stress score is decreases.**
# - **The profit margin and cash reserves shows the cluster in the bottom in 0 to 40 range**

# %%
plt.figure(figsize=(8, 5))
sns.violinplot(data=df, x='Industry', y='Profit_Margin', hue='Industry', palette="tab10", legend=False)
plt.title("Distribution of Profit_Margin by Industry")
plt.xlabel("Industry")
plt.ylabel("Profit_Margin")
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# - **Retail has the biggest industry and data is distriubuted in 4 to 30 profit margin**
# - **The 50% profit margin spread in 12 to 23 range and meadian near to 17**
# - **It shows high level outliers present in the retail industry**
# - **Food has the samllest industry and data is distributed in 13 to 22 profit margin**
# - **The 50% profit margin spread in 18 to 22 range and meadian near to 20**
# - **It shows extreme low level outliers present in the retail industry**
